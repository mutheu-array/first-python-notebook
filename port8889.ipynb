# %%
import pandas as pd

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs
# Out:
#        calaccess_committee_id  \
# 0                     1386560
# 1                     1386560
# 2                     1386560
# 3                     1386560
# 4                     1386560
# 5                     1386560
# 6                     1386560
# 7                     1386560
# 8                     1386560
# 9                     1386560
# 10                    1386560
# 11                    1386560
# 12                    1386560
# 13                    1386560
# 14                    1386560
# 15                    1386560
# 16                    1386560
# 17                    1386560
# 18                    1386560
# 19                    1386560
# 20                    1386560
# 21                    1386560
# 22                    1386560
# 23                    1386560
# 24                    1386560
# 25                    1386560
# 26                    1372902
# 27                    1372902
# 28                    1372902
# 29                    1372902
# ...

# %%
props.committee_name.value_counts()
# Out:
# MILLION VOTER PROJECT ACTION FUND - YES ON 55, 56, 57, 58, 62, AND NO ON 66, SPONSORED BY SOCIAL JUSTICE ADVOCATES AND ORGANIZATIONS                                                                      6
# FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))                                                                                                                                                              4
# PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON PROFIT 501 (C) (3))                                                                                                                                          3
# MILLION VOTER PROJECT ACTION FUND - YES ON 55 AND 57, SPONSORED BY SOCIAL JUSTICE ORGANIZATIONS                                                                                                           3
# ...

# %%
props.committee_name.value_counts.reset_index()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-54-6fad7c17520a> in <module>()
# ----> 1 props.committee_name.value_counts.reset_index()
#
# AttributeError: 'function' object has no attribute 'reset_index'

# %%
props.committee_name[props.prop_name == 'PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.'].value_counts()
# Out:
# CALIFORNIA GROCERS ASSOCIATION ISSUES COMMITTEE (NON-PROFIT 501(C) 6): YES ON PROPOSITION 67                                                                                                       1
# YES ON 67 - PROTECT THE PLASTIC BAG BAN, SPONSORED BY ENVIRONMENTAL AND OCEAN PROTECTION ORGANIZATIONS, BUSINESSES INCLUDING GROCERS AND REUSABLE BAG MAKERS, AND OTHER NONPROFIT ORGANIZATIONS    1
# YES ON 67 - CALIFORNIANS AGAINST WASTE - PROTECT THE PLASTIC BAN (NON-PROFIT 501 (C) (4))                                                                                                          1
# SAVE THE BAY ACTION FUND PAC - YES ON PROP 67                                                                                                                                                      1
# SAVE THE BAY ACTION FUND COMMITTEE TO SUPPORT PROPOSITION 67                                                                                                                                       1
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props[props.prop_name == "PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 23  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 24  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 25  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 26  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 27  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 28  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 29  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 30  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 31  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 32  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 33  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 34  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
#
# ...

# %%
Mari = props[props.prop_name == "PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]

# %%
Mari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 23 to 34
# Data columns (total 8 columns):
# ocd_prop_id               12 non-null object
# calaccess_prop_id         12 non-null int64
# ccdc_prop_id              12 non-null int64
# prop_name                 12 non-null object
# ccdc_committee_id         12 non-null int64
# calaccess_committee_id    12 non-null int64
# committee_name            12 non-null object
# committee_position        12 non-null object
# dtypes: int64(4), object(4)
# memory usage: 672.0+ bytes

# %%
pd.merge(Mari, contribs, on="calaccess_committee_id")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 2    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 3    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 4    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 5    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 6    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 7    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 8    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 9    ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 10   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 11   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# ...

# %%
merged = pd.merge(Mari, contribs, on="calaccess_committee_id")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 0 to 164
# Data columns (total 20 columns):
# ocd_prop_id                     165 non-null object
# calaccess_prop_id               165 non-null int64
# ccdc_prop_id                    165 non-null int64
# prop_name                       165 non-null object
# ccdc_committee_id               165 non-null int64
# calaccess_committee_id          165 non-null int64
# committee_name_x                165 non-null object
# committee_position              165 non-null object
# committee_name_y                165 non-null object
# calaccess_filing_id             165 non-null int64
# date_received                   165 non-null object
# contributor_lastname            165 non-null object
# contributor_firstname           65 non-null object
# contributor_city                165 non-null object
# contributor_state               165 non-null object
# contributor_zip                 165 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 88369291.670000002

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    119
# OPPOSE      46
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
support.amount.sum()
# Out:
# 33683287.670000002

# %%
oppose.amount.sum()
# Out:
# 54686004.0

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.38116507480657957

# %%
oppose.amount.sum() / merged.amount.sum()
# Out:
# 0.61883492519342043

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 29   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 36   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 83   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 24   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 30   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 37   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 25   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 119  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 74   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 103  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 102  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 138  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# ...

# %%
support.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 83   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 119  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 74   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 103  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 102  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 138  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 44   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 49   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 46   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 45   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 42   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 43   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# ...

# %%
merged.groupby(["committee_name_x", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                      committee_name_x committee_position  \
# 6   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....             OPPOSE
# 9   YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...            SUPPORT
# 5   MILLION VOTER PROJECT ACTION FUND - YES ON 55,...            SUPPORT
# 3   FIGHT CANCER - YES ON 56, SPONSORED BY AMERICA...            SUPPORT
# 4   MILLION VOTER PROJECT ACTION FUND - YES ON 55 ...            SUPPORT
# 1   CALIFORNIA KIDS CAMPAIGN, YES ON PROPS 55 & 56...            SUPPORT
# 2   COMMON SENSE KIDS ACTION, INC., YES ON PROPS. ...            SUPPORT
# 10  YES ON 56 STOP CANCER - PLANNED PARENTHOOD ADV...            SUPPORT
# 11  YES ON 56 STOP CANCER - PLANNED PARENTHOOD OF ...            SUPPORT
# 7   PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON P...            SUPPORT
# 0   CALIFORNIA CITIZENS AGAINST SPECIAL INTERESTS ...             OPPOSE
# 8   PROTECT SMALL BUSINESS AND SMOKE FREE ALTERNAT...             OPPOSE
#
#          amount
# ...

# %%
support.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x       amount
# 6  YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...  29267861.00
# 4  MILLION VOTER PROJECT ACTION FUND - YES ON 55,...   2110000.00
# 2  FIGHT CANCER - YES ON 56, SPONSORED BY AMERICA...    801450.00
# 3  MILLION VOTER PROJECT ACTION FUND - YES ON 55 ...    426035.55
# 0  CALIFORNIA KIDS CAMPAIGN, YES ON PROPS 55 & 56...    295000.00
# 1  COMMON SENSE KIDS ACTION, INC., YES ON PROPS. ...    295000.00
# 7  YES ON 56 STOP CANCER - PLANNED PARENTHOOD ADV...    250000.00
# 8  YES ON 56 STOP CANCER - PLANNED PARENTHOOD OF ...    200000.00
# 5  PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON P...     37941.12

# %%
oppose.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x      amount
# 1  NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....  54650500.0
# 0  CALIFORNIA CITIZENS AGAINST SPECIAL INTERESTS ...     32050.0
# 2  PROTECT SMALL BUSINESS AND SMOKE FREE ALTERNAT...      3454.0

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)
# Out:
#         contributor_firstname  \
# 50                  THOMAS F.
# 49                     THOMAS
# 34                 MICHAEL R.
# 17  FIGHT CANCER - YES ON 56,
# 28                    M QUINN
# 15                  ELIZABETH
# 9                     CAITLIN
# 24                    KAITLYN
# 4                        ANNE
# 2                   ALEXANDRA
#
#                                  contributor_lastname committee_position  \
# 50                                             STEYER            SUPPORT
# 49                                             STEYER            SUPPORT
# 34                                          BLOOMBERG            SUPPORT
# 17  SPONSORED BY AMERICAN CANCER SOCIETY, INC. AND...            SUPPORT
# 28                                            DELANEY            SUPPORT
# 15                                             SIMONS            SUPPORT
# 9                                             HEISING            SUPPORT
# ...

# %%
support.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#         contributor_firstname  \
# 47                  THOMAS F.
# 46                     THOMAS
# 32                 MICHAEL R.
# 16  FIGHT CANCER - YES ON 56,
# 26                    M QUINN
# 8                     CAITLIN
# 14                  ELIZABETH
# 22                    KAITLYN
# 4                        ANNE
# 2                   ALEXANDRA
# 0                        ADAM
# 41                        SAM
# 18                       JOHN
# 31                    MICHAEL
# 35                     PHILIP
# 1                        ALAN
# 36                    RICHARD
# 12                     DENICE
# 38                     ROBERT
# 7                        BART
# 5                       APRIL
# 21                   JULIETTE
# 25                      LAURA
# 13                      DIANA
# 10                       DALE
# 50                    WILLIAM
# 33                       PAUL
# 42                    SEYMOUR
# 49                    TIMOTHY
# 48                        TIM
# ...

# %%
oppose.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#   contributor_firstname contributor_lastname  amount
# 0                 BRIAN              TELFORD  1000.0
# 1                   JAN               PARCEL   350.0
# 2                   THE  VAPOUR LOUNGE, INC.   100.0
